# %% [markdown]
# # Proyecto 1er Parcial - Análisis de Datos

# %% [markdown]
# **Facultad de Ingeniería en Ciencias de la Tierra**
#
# *Maestría en Ciencias de la Tierra*
#
# **Integrantes** : Janner Galarza y Cindy Goyburo

# %% [markdown]
# ## Introducción
# <p style="text-align: justify;">La preservación del recurso agua está contemplado dentro de los ODS del programa de las naciones unidas (PNUD), que establece la importancia de
# asegurar la disponibilidad y la gestión sostenible de fuentes de agua limpia para todos [1]. Sin embargo, en países en vía de desarrollo estás fuentes de agua suelen estar contaminadas, debido a la falta de control y regulación de las actividades antropogénicas que se realizan en zonas cercanas a los cuerpos hídricos[2].</p>
#
# <p style="text-align: justify;">Ecuador es uno de los países latinoamericanos con mayor cantidad de agua dulce, sin embargo, el 40% de la población rural no posee acceso al agua para consumo humano. Otro de los problemas persistentes es que el 90% de las aguas residuales no poseen un correcto tratamiento. Lo que conlleva a que más del 50% de las fuentes de agua dulce no sean aptas para el consumo debido a su pésima calidad[3].</p>
#
# <p style="text-align: justify;">Las actividades industriales que no poseen un correcto control de los desechos residuales que generan han provocado en gran cantidad el deterioro del medio ambiente, y han influido directamente en la calidad del agua, algunas de las principales malas prácticas ambientales son las descargas de aguas con altos niveles de metales pesados en ríos y quebradas, causando la degradación de la flora y la fauna y afectando a los usuarios que hacen uso de los ríos[4]. En este contexto, el objetivo de este proyecto es evaluar espacial y temporalmente el contenido de elementos potencialmente tóxicos en cuerpos de agua con fines de consumo, en el área minera de Santa Rosa, mediante la utilización de la analítica de datos.</p>
#
# ## Objetivo
# <p style="text-align: justify;">Analizar la concentración de metales pesados en la cuenca del río Santa Rosa utilizando las bibliotecas de Python numpy, pandas, matplotlib y seaborn, para la identificación de tendencias y comportamientos durante la época seca y lluviosa del año 2021.</p>

# %% [markdown]
# ## Metodología y resultados
#
# Se utilizaron las librerías y métodos estudiados en clase. Los resultados se van obteniendo a medida que se desarrolla el código.

# %% [markdown]
# ### Carga de datos y librerías a utilizar

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Carga y procesamiento de los datos

# %%
#Cargar el conjunto de datos utilizando pandas o la librería más adecuada para el tipo de archivo que será importado.

# %%
#Época seca 2021
dryS_2021 = pd.read_excel('dry season 2021.xlsx')
dryS_2021.head()
# Out:
#        COD       X        Y    pH  Temp     EC    TDS         As         Al   \
# 0  AS - 05  628525  9602778  7.18  23.4   95.3   80.0   4.921527   11.763710
# 1  AS - 06  626514  9602949  6.63  23.2  312.0  348.0  57.248326  100.665891
# 2  AS - 08  628465  9602897  7.38  24.2   75.5  123.1   6.435689   31.816725
# 3  AS - 09  626391  9602960  7.23  24.7  121.9   83.0   5.615994   12.416447
# 4  AS - 10  620486  9603987  7.10  25.2  131.3  104.9  16.068989   25.993162
#
#          Cr  ...         Zn       Mo        Cd         Pb    Na         Mg   \
# 0  0.048149  ...  39.193544  0.043444  0.524854  0.198011    NaN   4.226642
# 1  0.266866  ...  45.440573  0.720994  2.500808  1.029583    NaN  33.199734
# 2  0.104965  ...   3.763228  1.379077  0.033469  0.143071    NaN   6.504139
# 3  0.090028  ...   4.624054  0.363459  0.046482  0.192393    NaN   5.079142
# 4  0.093840  ...   3.312821  0.604068  0.036424  0.147907    NaN   9.118661
#
#            P        K         Ca      Epoca
# ...

# %%
#Época lluviosa 2021
rainyS_2021 = pd.read_excel('rainy season 2021.xlsx')
rainyS_2021.head()
# Out:
#        COD       X        Y    pH  Temp      EC     TDS         As  \
# 0  AS - 01  627328  9604933  9.35  22.4  975.00  670.00   4.503418
# 1  AS - 02  627257  9604583  8.03  25.7  245.00  165.20  16.605881
# 2  AS - 03  628870  9605538  8.18  20.9   26.10   16.28   2.234928
# 3  AS - 04  628748  9605430  5.62  21.0  199.20  149.60   1.486321
# 4  AS - 05  628525  9602778  7.75  23.1  112.01   85.30   1.277614
#
#           Al         Cr  ...          Zn       Mo        Cd         Pb  \
# 0   25.351403  0.096905  ...   22.820252  0.039933  0.180057  0.053490
# 1  141.592365  0.259379  ...   12.062780  0.237764  0.064377  0.063609
# 2   16.209645  0.195742  ...    7.694590  0.090921  0.147944  0.036539
# 3   35.860385  0.471555  ...   32.679681  0.200922  0.734175  0.100879
# 4  701.669485  0.243742  ...  220.863884  0.011384  2.486777  0.744523
#
#         Na        Mg           P         K         Ca        Epoca
# 0  3.032555  2.836554   1.206627   8.906215   3.473303  RAINY-2021
# ...

# %%
#Limpieza de la data

# %%
#Para le época seca 2021
dryS_2021.drop_duplicates(inplace=True)
dryS_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   COD     15 non-null     object
#  1   X       15 non-null     int64
#  2   Y       15 non-null     int64
#  3   pH      15 non-null     float64
#  4   Temp    15 non-null     float64
#  5   EC      15 non-null     float64
#  6   TDS     15 non-null     float64
#  7     As    15 non-null     float64
#  8   Al      15 non-null     float64
#  9     Cr    15 non-null     float64
#  10    Mn    15 non-null     float64
#  11    Fe    15 non-null     float64
#  12    Co    15 non-null     float64
#  13    Ni    15 non-null     float64
#  14    Cu    15 non-null     float64
#  15    Zn    15 non-null     float64
#  16    Mo    15 non-null     float64
#  17  Cd      15 non-null     float64
#  18  Pb      15 non-null     float64
#  19    Na    0 non-null      float64
#  20    Mg    15 non-null     float64
# ...

# %%
#Se identificó que los nombres de las columnas tenian espacio, entonces se procedio a limpiar y organizar la data
print(dryS_2021.columns)
dryS_2021.columns = dryS_2021.columns.str.strip()
dryS_2021.drop(dryS_2021.columns[-1], axis=1, inplace=True) #Eliminé la ultima columna que solo indicaba la época
dryS_2021.info()
# Out:
# Index(['COD', 'X', 'Y', 'pH', 'Temp', 'EC', 'TDS', '  As', 'Al ', '  Cr',
#        '  Mn', '  Fe', '  Co ', '  Ni ', '  Cu', '  Zn', '  Mo ', 'Cd ', 'Pb',
#        '  Na ', '  Mg ', '  P', '  K ', '  Ca ', 'Epoca'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   COD     15 non-null     object
#  1   X       15 non-null     int64
#  2   Y       15 non-null     int64
#  3   pH      15 non-null     float64
#  4   Temp    15 non-null     float64
#  5   EC      15 non-null     float64
#  6   TDS     15 non-null     float64
#  7   As      15 non-null     float64
#  8   Al      15 non-null     float64
#  9   Cr      15 non-null     float64
#  10  Mn      15 non-null     float64
#  11  Fe      15 non-null     float64
#  12  Co      15 non-null     float64
#  13  Ni      15 non-null     float64
# ...

# %%
#Para le época lluviosa 2021
print(rainyS_2021.columns)
rainyS_2021.columns = rainyS_2021.columns.str.strip()
rainyS_2021.drop(rainyS_2021.columns[-1], axis=1, inplace=True) #Eliminé la ultima columna que solo indicaba la época
rainyS_2021.info()
# Out:
# Index(['COD', 'X', 'Y', 'pH', 'Temp', 'EC', 'TDS', '  As', 'Al ', '  Cr',
#        '  Mn', '  Fe', '  Co ', '  Ni ', '  Cu', '  Zn', '  Mo ', 'Cd ', 'Pb',
#        '  Na ', '  Mg ', '  P', '  K ', '  Ca ', 'Epoca'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   COD     33 non-null     object
#  1   X       33 non-null     int64
#  2   Y       33 non-null     int64
#  3   pH      33 non-null     float64
#  4   Temp    33 non-null     float64
#  5   EC      33 non-null     float64
#  6   TDS     33 non-null     float64
#  7   As      33 non-null     float64
#  8   Al      33 non-null     float64
#  9   Cr      33 non-null     float64
#  10  Mn      33 non-null     float64
#  11  Fe      33 non-null     float64
#  12  Co      33 non-null     float64
#  13  Ni      33 non-null     float64
# ...

# %%
# Cambiar los nombres a los iones DRY SEASON 2021
dryS_2021.rename(columns={"Temp":"T (°C)","EC":"EC (uS/cm)",'TDS':'TDS (mg/L)', "Al":"Al","Na":'Na$^{+}$',"Mg":"Mg$^{+2}$","P":"P",'K':'K$^{+}$','Ca':'Ca$^{+2}$'}, inplace=True)
dryS_2021.tail()
# Out:
#         COD       X        Y    pH  T (°C)  EC (uS/cm)  TDS (mg/L)         As  \
# 10  AS - 24  619526  9604096  7.21    25.1       132.0        98.2  14.880331
# 11  AS - 25  618408  9604210  7.27    23.5       130.7       126.0  11.291875
# 12  AS - 26  617366  9605753  7.20    23.8       140.0       128.0  11.319051
# 13  AS - 27  616853  9606897  7.23    24.2       154.9       121.0   9.434813
# 14  AS - 28  616706  9607404  7.12    24.4       157.7       112.0  18.243393
#
#            Al        Cr  ...        Cu         Zn        Mo        Cd  \
# 10  56.864391  0.178114  ...  3.455712  13.821381  0.480340  0.161235
# 11  20.343157  0.210805  ...  2.735811   3.298248  0.410915  0.019513
# 12  19.435310  0.168086  ...  2.596744   2.941150  0.474404  0.020495
# 13  21.260557  0.148940  ...  2.524161   3.813380  0.417908  0.028135
# 14  12.133337  0.149793  ...  4.103974   2.332243  0.800751  0.020137
#
#           Pb  Na$^{+}$  Mg$^{+2}$          P   K$^{+}$  Ca$^{+2}$
# ...

# %%
# Cambiar los nombres a los iones Rainy SEASON 2021
rainyS_2021.rename(columns={"Temp":"T (°C)","EC":"EC (uS/cm)", 'TDS':'TDS (mg/L)', "Al":"Al","Na":'Na$^{+}$',"Mg":"Mg$^{+2}$","P":"P",'K':'K$^{+}$','Ca':'Ca$^{+2}$'}, inplace=True)
rainyS_2021.head()
# Out:
#        COD       X        Y    pH  T (°C)  EC (uS/cm)  TDS (mg/L)         As  \
# 0  AS - 01  627328  9604933  9.35    22.4      975.00      670.00   4.503418
# 1  AS - 02  627257  9604583  8.03    25.7      245.00      165.20  16.605881
# 2  AS - 03  628870  9605538  8.18    20.9       26.10       16.28   2.234928
# 3  AS - 04  628748  9605430  5.62    21.0      199.20      149.60   1.486321
# 4  AS - 05  628525  9602778  7.75    23.1      112.01       85.30   1.277614
#
#            Al        Cr  ...           Cu          Zn        Mo        Cd  \
# 0   25.351403  0.096905  ...     3.537233   22.820252  0.039933  0.180057
# 1  141.592365  0.259379  ...     6.207676   12.062780  0.237764  0.064377
# 2   16.209645  0.195742  ...     1.694006    7.694590  0.090921  0.147944
# 3   35.860385  0.471555  ...    39.191344   32.679681  0.200922  0.734175
# 4  701.669485  0.243742  ...  1039.908182  220.863884  0.011384  2.486777
#
# ...

# %% [markdown]
# ### Estadística de los datos

# %%
dryS_2021.describe()
# Out:
#                    X             Y         pH     T (°C)  EC (uS/cm)  \
# count      15.000000  1.500000e+01  15.000000  15.000000   15.000000
# mean   621961.333333  9.604338e+06   7.122000  24.186667  149.846667
# std      4949.769023  1.564052e+03   0.197129   0.691651   70.788799
# min    616706.000000  9.602778e+06   6.630000  23.200000   68.400000
# 25%    617612.500000  9.602974e+06   7.100000  23.650000  126.300000
# 50%    619526.000000  9.603987e+06   7.180000  24.200000  134.600000
# 75%    626551.500000  9.605206e+06   7.230000  24.850000  149.950000
# max    629310.000000  9.607404e+06   7.380000  25.200000  312.000000
#
#        TDS (mg/L)         As          Al         Cr          Mn  ...  \
# count   15.000000  15.000000   15.000000  15.000000   15.000000  ...
# mean   157.520000  19.831806   39.535753   0.168526   19.448651  ...
# std     93.745729  18.012727   31.006311   0.080461   31.434746  ...
# ...

# %%
rainyS_2021.describe()
# Out:
#                    X             Y         pH     T (°C)  EC (uS/cm)  \
# count      33.000000  3.300000e+01  33.000000  33.000000   33.000000
# mean   623439.818182  9.604492e+06   8.036667  23.212121  170.160303
# std      5049.895286  1.776895e+03   1.077777   3.935397  180.825330
# min    615934.000000  9.602778e+06   5.490000  14.900000   12.070000
# 25%    617728.000000  9.602989e+06   7.790000  22.400000   84.030000
# 50%    626391.000000  9.603987e+06   8.120000  25.100000  112.010000
# 75%    628465.000000  9.605430e+06   8.730000  25.700000  185.800000
# max    629310.000000  9.608627e+06   9.840000  27.200000  975.000000
#
#        TDS (mg/L)         As           Al         Cr           Mn  ...  \
# count   33.000000  33.000000    33.000000  33.000000    33.000000  ...
# mean   101.883939   4.991268   363.230984   0.235642   170.186639  ...
# std    119.465162   3.266076   798.319040   0.144501   375.158212  ...
# ...

# %% [markdown]
# ### Visualización (EDA)

# %%
#Visualizar la distribución de los datos
dryS_2021.head()
# Out:
#        COD       X        Y    pH  T (°C)  EC (uS/cm)  TDS (mg/L)         As  \
# 0  AS - 05  628525  9602778  7.18    23.4        95.3        80.0   4.921527
# 1  AS - 06  626514  9602949  6.63    23.2       312.0       348.0  57.248326
# 2  AS - 08  628465  9602897  7.38    24.2        75.5       123.1   6.435689
# 3  AS - 09  626391  9602960  7.23    24.7       121.9        83.0   5.615994
# 4  AS - 10  620486  9603987  7.10    25.2       131.3       104.9  16.068989
#
#            Al        Cr  ...         Cu         Zn        Mo        Cd  \
# 0   11.763710  0.048149  ...  21.340125  39.193544  0.043444  0.524854
# 1  100.665891  0.266866  ...   4.897015  45.440573  0.720994  2.500808
# 2   31.816725  0.104965  ...   2.250795   3.763228  1.379077  0.033469
# 3   12.416447  0.090028  ...   2.256711   4.624054  0.363459  0.046482
# 4   25.993162  0.093840  ...   3.128431   3.312821  0.604068  0.036424
#
#          Pb  Na$^{+}$  Mg$^{+2}$          P   K$^{+}$  Ca$^{+2}$
# ...

# %%
# Época seca
fig, ax =  plt.subplots()
ax.scatter(dryS_2021["COD"], dryS_2021["As"], c="b", alpha=0.25)

# Set labels
ax.set_xlabel("Código de muestra")
ax.set_ylabel("Concentración As (mg/L)")
ax.set_title("Distribución de As en la época seca del año 2021 a lo largo del río Santa Rosa")


ax.grid()
ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(5))

ax.grid(which='minor', linestyle=':', linewidth='0.5', color='green')
plt.xticks(rotation=45) #mejora la legibilidad de las etiquetas del eje x
plt.tight_layout() #ajustar automáticamente los parámetros de los ejes para que el contenido de los gráficos se ajuste bien a la figura.

plt.show()

# %%
# Época lluviosa
fig, ax =  plt.subplots(figsize=(10,6))
ax.scatter(rainyS_2021["COD"], rainyS_2021["As"], c="b", alpha=0.25)

# Set labels
ax.set_xlabel("Código de muestra")
ax.set_ylabel("Concentración As (mg/L)")
ax.set_title("Distribución de As en la época lluviosa del año 2021 a lo largo del río Santa Rosa")


ax.grid()
ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(2))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(5))

ax.grid(which='minor', linestyle=':', linewidth='0.5', color='green')
plt.xticks(rotation=45) #mejora la legibilidad de las etiquetas del eje x
plt.tight_layout() #ajustar automáticamente los parámetros de los ejes para que el contenido de los gráficos se ajuste bien a la figura.

plt.show()

# %%
#Posibles outliers

# %%
dryS_2021.describe() #para el elemento cromo los posibles outliers corresponderá a los valores que se enceuntren por encima de 0.33 mg/L.
# Out:
#                    X             Y         pH     T (°C)  EC (uS/cm)  \
# count      15.000000  1.500000e+01  15.000000  15.000000   15.000000
# mean   621961.333333  9.604338e+06   7.122000  24.186667  149.846667
# std      4949.769023  1.564052e+03   0.197129   0.691651   70.788799
# min    616706.000000  9.602778e+06   6.630000  23.200000   68.400000
# 25%    617612.500000  9.602974e+06   7.100000  23.650000  126.300000
# 50%    619526.000000  9.603987e+06   7.180000  24.200000  134.600000
# 75%    626551.500000  9.605206e+06   7.230000  24.850000  149.950000
# max    629310.000000  9.607404e+06   7.380000  25.200000  312.000000
#
#        TDS (mg/L)         As          Al         Cr          Mn  ...  \
# count   15.000000  15.000000   15.000000  15.000000   15.000000  ...
# mean   157.520000  19.831806   39.535753   0.168526   19.448651  ...
# std     93.745729  18.012727   31.006311   0.080461   31.434746  ...
# ...

# %%
# Época seca

codigos = ['AS - 05', 'AS - 06', 'AS - 08', 'AS - 09']
datos_metal= dryS_2021[dryS_2021["COD"].isin(codigos)]

fig, ax = plt.subplots(figsize=(8,6))
sns.boxplot(data=datos_metal, x= "COD", y = "T (°C)", ax=ax, width= 0.5)


ax.set_xlabel("Código de muestra")
ax.set_ylabel("As (mg/L)")
ax.set_title("Box Plot For Cr (mg/L)")

ax.grid()
ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(10))
#ax.set_ylim(0, 0.8)

ax.grid(which='minor', linestyle=':', linewidth='0.5', color='green')
plt.tight_layout() #ajustar automáticamente los parámetros de los ejes para que el contenido de los gráficos se ajuste bien a la figura.

plt.show()

#Este tipo de visualización puede darse dado que por la naturaleza del muestreo, los códigos no se repiten por lo tanto cada código tiene un unico valor.

# %%
# Época lluviosa
de_grouped = rainyS_2021.groupby("COD")["Cr"].max().reset_index()
def_sorted = rainyS_2021.sort_values(by="Cr", ascending=False)

fig, ax = plt.subplots(figsize=(14,8))

sns.boxplot(data=rainyS_2021, x= "COD", y = "Cr")

ax.set_xlabel("Código de muestra")
ax.set_ylabel("Cr (mg/L)")
ax.set_title("Box Plot For Cr (mg/L)")

ax.grid()
ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(2))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(2))
ax.set_ylim(0, 0.8)

ax.grid(which='minor', linestyle=':', linewidth='0.5', color='green')
plt.xticks(rotation=45) #mejora la legibilidad de las etiquetas del eje x
plt.tight_layout() #ajustar automáticamente los parámetros de los ejes para que el contenido de los gráficos se ajuste bien a la figura.


plt.show()
#Este tipo de visualización puede darse dado que por la naturaleza del muestreo, los códigos no se repiten por lo tanto cada código tiene un unico valor.

# %% [markdown]
# ### Funciones - Limpar Data

# %%
# limpiar la data de espacios vacios y duplicados
def eliminar_duplicados(data, keep="First"):
    return data.drop_duplicates(inplace=True)
    
dup = eliminar_duplicados(rainyS_2021)
print(dup)


def espacios_vacios(data):
    data_limp = data.columns = data.columns.str.strip()
    return data_limp

sin_espacios = espacios_vacios(dryS_2021)
print(sin_espacios)
# Out:
# None
# Index(['COD', 'X', 'Y', 'pH', 'T (°C)', 'EC (uS/cm)', 'TDS (mg/L)', 'As', 'Al',
#        'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn', 'Mo', 'Cd', 'Pb', 'Na$^{+}$',
#        'Mg$^{+2}$', 'P', 'K$^{+}$', 'Ca$^{+2}$'],
#       dtype='object')

# %% [markdown]
# ### Funciones - Agregar y agrupar

# %%
# Agrupar y agregar información de los datos 
# Época seca
def agrupar_agregar(data, column, agg_colum, funciones_agregacion): 
    agrupado = data.groupby(column).agg({agg_colum: funciones_agregacion})
    return agrupado

agregar = agrupar_agregar(dryS_2021, "COD", "T (°C)",["sum", "mean", "count"]).reset_index()
print("Multiples agregaciones por código:")
agregar.head()
# Out:
# Multiples agregaciones por código:
#        COD T (°C)
#               sum  mean count
# 0  AS - 05   23.4  23.4     1
# 1  AS - 06   23.2  23.2     1
# 2  AS - 08   24.2  24.2     1
# 3  AS - 09   24.7  24.7     1
# 4  AS - 10   25.2  25.2     1

# %% [markdown]
# ### Funciones - Información estadística

# %%
def estadistica(data):
    return data.describe()

dr_estadist = estadistica(dryS_2021)
dr_estadist
# Out:
#                    X             Y         pH     T (°C)  EC (uS/cm)  \
# count      15.000000  1.500000e+01  15.000000  15.000000   15.000000
# mean   621961.333333  9.604338e+06   7.122000  24.186667  149.846667
# std      4949.769023  1.564052e+03   0.197129   0.691651   70.788799
# min    616706.000000  9.602778e+06   6.630000  23.200000   68.400000
# 25%    617612.500000  9.602974e+06   7.100000  23.650000  126.300000
# 50%    619526.000000  9.603987e+06   7.180000  24.200000  134.600000
# 75%    626551.500000  9.605206e+06   7.230000  24.850000  149.950000
# max    629310.000000  9.607404e+06   7.380000  25.200000  312.000000
#
#        TDS (mg/L)         As          Al         Cr          Mn  ...  \
# count   15.000000  15.000000   15.000000  15.000000   15.000000  ...
# mean   157.520000  19.831806   39.535753   0.168526   19.448651  ...
# std     93.745729  18.012727   31.006311   0.080461   31.434746  ...
# ...

# %% [markdown]
# ### Funciones - Generador de gáficos

# %%
def generador_graficos(data, codigo, elemento, xlabel, ylabel, title):
       
    fig, ax = plt.subplots(figsize=(14,8))

    ax.plot(dryS_2021[codigo],dryS_2021[elemento])
    
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    
    ax.grid()
    
    ax.fill_between(dryS_2021[codigo], dryS_2021[elemento] , color="pink", alpha=0.33)
    
    ax.minorticks_on()
    ax.xaxis.set_minor_locator(ticker.MultipleLocator(10))
    ax.yaxis.set_minor_locator(ticker.MultipleLocator(500))
    
    ax.grid(which='minor', linestyle=':', linewidth='0.5', color='pink')
    
    ax.grid()
    ax.minorticks_on()
    ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_minor_locator(ticker.MultipleLocator(5))
    ax.grid(which='minor', linestyle=':', linewidth='0.5', color='green')
    plt.xticks(rotation=45) #mejora la legibilidad de las etiquetas del eje x
    plt.tight_layout() #ajustar automáticamente los parámetros de los ejes para que el contenido de los gráficos se ajuste bien a la figura.
    
    plt.show()

graficos = generador_graficos(dryS_2021, "COD", "Al", xlabel= "Código de muestra", ylabel='Concentración de Al (mg/L)', title='Variación de la concentración de Al, a lo largo del río Santa Rosa')
graficos

# %% [markdown]
# ### Visualización de Datos

# %% [markdown]
# ### Distribución de variables numéricas

# %%
# Época seca
fig, ax =  plt.subplots(figsize=(10,6))
ax.scatter(dryS_2021["COD"], dryS_2021["pH"], c="b", alpha=0.25)

# Set labels
ax.set_xlabel("Código de muestra")
ax.set_ylabel("pH")
ax.set_title("Cambio del pH en la época seca del año 2021 a lo largo del río Santa Rosa")

ax.grid()
ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.5))

ax.grid(which='minor', linestyle=':', linewidth='0.5', color='green')
plt.xticks(rotation=45) #mejora la legibilidad de las etiquetas del eje x
plt.tight_layout() #ajustar automáticamente los parámetros de los ejes para que el contenido de los gráficos se ajuste bien a la figura.

plt.show()

# %%
# Época lluviosa
fig, ax =  plt.subplots(figsize=(10,6))
ax.scatter(rainyS_2021["COD"], rainyS_2021["pH"], c="b", alpha=0.25)

# Set labels
ax.set_xlabel("Código de muestra")
ax.set_ylabel("pH")
ax.set_title("Cambio del pH en la época lluviosa del año 2021 a lo largo del río Santa Rosa")


ax.grid()
ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.5))

ax.grid(which='minor', linestyle=':', linewidth='0.5', color='green')
plt.xticks(rotation=45) #mejora la legibilidad de las etiquetas del eje x
plt.tight_layout() #ajustar automáticamente los parámetros de los ejes para que el contenido de los gráficos se ajuste bien a la figura.

plt.show()

# %% [markdown]
# ### Distribución de las variables categóricas

# %%
#Comportamiento de variables categóricas

# %%
#Época seca

fig, ax =  plt.subplots(figsize=(10,6))

sns.barplot(data=dryS_2021, x="COD", y='pH')

# Set labels
ax.set_xlabel("Código de muestra")
ax.set_ylabel("pH")
ax.set_title("pH a lo largo del río Santa Rosa en la época seca del año 2021")

ax.grid()
ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(25))
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='green')
plt.xticks(rotation=45) #mejora la legibilidad de las etiquetas del eje x
plt.tight_layout() #ajustar automáticamente los parámetros de los ejes para que el contenido de los gráficos se ajuste bien a la figura.


plt.show()

# %%
#Época lluviosa

fig, ax =  plt.subplots(figsize=(14,8))

sns.barplot(data=rainyS_2021, x="COD", y='pH')

# Set labels
ax.set_xlabel("Código de muestra")
ax.set_ylabel("pH")
ax.set_title("pH a lo largo del río Santa Rosa en la época lluviosa del año 2021")

ax.grid()
ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(25))
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='green')
plt.xticks(rotation=45) #mejora la legibilidad de las etiquetas del eje x
plt.tight_layout() #ajustar automáticamente los parámetros de los ejes para que el contenido de los gráficos se ajuste bien a la figura.


plt.show()

# %%
#Tendencias de alguna variable a lo largo del tiempo (gráficos de líneas)

# %%
# Época seca

fig, ax = plt.subplots(figsize=(14,8))

#"Na":'Na$^{+}$',"Mg":"Mg$^{+2}$","P":"P",'K':'K$^{+}$','Ca':'Ca$^{+2}$'

ax.plot(dryS_2021['COD'],dryS_2021['Na$^{+}$'], label = 'Na')
ax.plot(dryS_2021['COD'],dryS_2021['Mg$^{+2}$'], label = 'Mg')
ax.plot(dryS_2021['COD'],dryS_2021['K$^{+}$'], label = 'K')
ax.plot(dryS_2021['COD'],dryS_2021['Ca$^{+2}$'], label = 'Ca')

ax.set_title("Distribución de cationes a los largo del río Santa Rosa, en el año 2021")
ax.set_xlabel('Código de muestra')
ax.set_ylabel("Concentraciones (ug/L)")
ax.legend()
ax.grid()

ax.fill_between(dryS_2021['COD'], dryS_2021['Ca$^{+2}$'] , color="pink", alpha=0.33)

ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(10))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(500))

ax.grid(which='minor', linestyle=':', linewidth='0.5', color='pink')

ax.grid()
ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(5))
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='green')
plt.xticks(rotation=45) #mejora la legibilidad de las etiquetas del eje x
plt.tight_layout() #ajustar automáticamente los parámetros de los ejes para que el contenido de los gráficos se ajuste bien a la figura.

plt.show()

# %%
# Época seca

fig, ax = plt.subplots(figsize=(14,8))

#"Na":'Na$^{+}$',"Mg":"Mg$^{+2}$","P":"P",'K':'K$^{+}$','Ca':'Ca$^{+2}$'

ax.plot(dryS_2021['COD'],dryS_2021['Fe'], label = 'Fe')
ax.plot(dryS_2021['COD'],dryS_2021['As'], label = 'As')
ax.plot(dryS_2021['COD'],dryS_2021['Cr'], label = 'Cr')
ax.plot(dryS_2021['COD'],dryS_2021['Mn'], label = 'Mn')

ax.set_title("Distribución de metales a los largo del río Santa Rosa, en el año 2021")
ax.set_xlabel('Código de muestra')
ax.set_ylabel("Concentraciones (ug/L)")
ax.legend()
ax.grid()

ax.fill_between(dryS_2021['COD'], dryS_2021['As'] , color="pink", alpha=0.33)

ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(10))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(500))

ax.grid(which='minor', linestyle=':', linewidth='0.5', color='pink')

ax.grid()
ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(5))
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='green')
plt.xticks(rotation=45) #mejora la legibilidad de las etiquetas del eje x
plt.tight_layout() #ajustar automáticamente los parámetros de los ejes para que el contenido de los gráficos se ajuste bien a la figura.

plt.show()

# %%
# Época seca

fig, ax = plt.subplots(figsize=(14,8))

#"Na":'Na$^{+}$',"Mg":"Mg$^{+2}$","P":"P",'K':'K$^{+}$','Ca':'Ca$^{+2}$'

ax.plot(rainyS_2021['COD'],rainyS_2021['Fe'], label = 'Fe')
ax.plot(rainyS_2021['COD'],rainyS_2021['As'], label = 'As')
ax.plot(rainyS_2021['COD'],rainyS_2021['Cr'], label = 'Cr')
ax.plot(rainyS_2021['COD'],rainyS_2021['Mn'], label = 'Mn')

ax.set_title("Distribución de metales a los largo del río Santa Rosa, en el año 2021")
ax.set_xlabel('Código de muestra')
ax.set_ylabel("Concentraciones (ug/L)")
ax.legend()
ax.grid()

ax.fill_between(rainyS_2021['COD'], rainyS_2021['As'] , color="red", alpha=0.33)

ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(10))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(50))

ax.grid(which='minor', linestyle=':', linewidth='0.5', color='pink')

ax.grid()
ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(500))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(50))
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='green')
plt.xticks(rotation=45) #mejora la legibilidad de las etiquetas del eje x
plt.tight_layout() #ajustar automáticamente los parámetros de los ejes para que el contenido de los gráficos se ajuste bien a la figura.

plt.show()

# %%
#Época lluviosa

fig, ax = plt.subplots(figsize=(10,8))

#"Na":'Na$^{+}$',"Mg":"Mg$^{+2}$","P":"P",'K':'K$^{+}$','Ca':'Ca$^{+2}$'

ax.plot(rainyS_2021['COD'],rainyS_2021['Na$^{+}$'], label = 'Na')
ax.plot(rainyS_2021['COD'],rainyS_2021['Mg$^{+2}$'], label = 'Mg')
ax.plot(rainyS_2021['COD'],rainyS_2021['K$^{+}$'], label = 'K')
ax.plot(rainyS_2021['COD'],rainyS_2021['Ca$^{+2}$'], label = 'Ca')

ax.set_title("Distribución de cationes a los largo del río Santa Rosa, en el año 2021")
ax.set_xlabel('Código de muestra')
ax.set_ylabel("Concentraciones (mg/L)")
ax.legend()
ax.grid()

ax.fill_between(rainyS_2021['COD'], rainyS_2021['Ca$^{+2}$'] , color="pink", alpha=0.33)

ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(10))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(500))

ax.grid(which='minor', linestyle=':', linewidth='0.5', color='pink')

ax.grid()
ax.minorticks_on()
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(5))
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='green')
plt.xticks(rotation=45) #mejora la legibilidad de las etiquetas del eje x
plt.tight_layout() #ajustar automáticamente los parámetros de los ejes para que el contenido de los gráficos se ajuste bien a la figura.

plt.show()

# %% [markdown]
# ### Conclusiones
# 1. Se identificó que en ambas épocas del año 2021, el elemento con mayor concentración en las muestras de agua superficial fue el calcio.
# 2. De forma general, las concentración de iones y metales durante la época seca fueron mayor que durante la época lluviosa.
# 3. La concentración de sales y metales puede distribuirse a lo largo del río Santa Rosa debio al aumento del nivel del agua en los ríos por las lluvias.
# 4. Se identificó que los valores máximos de sales y metales se encontraban en las muestras que fueorn tomadas en las quebradas, esto puede deberse a la presencia de actividad minera.
# 5. El uso de librerías como seaborn permite generar gráficos de análisis de datos de alta calidad que pueden ser presentados en articulos científicos.

# %% [markdown]
# ### Recomendaciones
#
# 1. Utilizar jerarquía de datos para optimizar la visualización y organización de los datos.
# 2. Crear funciones que faciliten la reutilización de estructuras para elaborar figuras y demas procesos sin tener que reescribir el código.
# 3. Utilizar Seaborn puede ofrecer una intefaz mucho más llamativa que maltplotlib y otros graficadores externos.
# 4. Ser ordenado en la elaboración del código facilita la interacción y lectura de los bloques de código.

# %% [markdown]
# ### Referencias biliográficas
#
# [1] “Sustainable Development Goals | United Nations Development Programme.”
# Accessed: Jun. 08, 2024. [Online]. Available: https://www.undp.org/sustainabledevelopment-goals
#
# [2] P. Campoverde-Muñoz et al., “Risk Assessment of Groundwater Contamination in the
# Gala, Tenguel, and Siete River Basins, Ponce Enriquez Mining Area-Ecuador,”
# Sustainability, vol. 15, no. 1, p. 403, 2022, doi: 10.3390/su15010403.
#
# [3] F. F. Latinoamericano, “Futuro del Agua en el Ecuador Perspectivas presidenciales -
# Fundación Futuro Latinoamericano.” Accessed: Jan. 09, 2023. [Online]. Available:
# https://www.ffla.net/es/futuro-del-agua-en-el-ecuador-perspectivas-presidenciales/
#
# [4] N. Yaraghi, A. K. Ronkanen, A. Torabi Haghighi, M. Aminikhah, K. Kujala, and B. Kløve,
# “Impacts of gold mine effluent on water quality in a pristine sub-Arctic river,” J Hydrol
# (Amst), vol. 589, Oct. 2020, doi: 10.1016/J.JHYDROL.2020.125170.

# %% [markdown]
# ### [GitHub](https://github.com/cindy-goyburo/an-lisis-project)
